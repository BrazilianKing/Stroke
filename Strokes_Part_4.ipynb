# %% [markdown]
# <a href="https://colab.research.google.com/github/BrazilianKing/Stroke/blob/main/Strokes_Part_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## Pandas
import pandas as pd
## Numpy
import numpy as np
# MatPlotLib
import matplotlib.pyplot as plt
# Preprocessing 
from sklearn.compose import make_column_selector, make_column_transformer

# %%
df = pd.read_csv('/content/drive/MyDrive/excel downloads/healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
#drop column 'id' because it is not needed 

df = df.drop(columns = 'id')

# %% [markdown]
# The ID # of the client has no effect on if they get a stroke or not.

# %%
# Display the number of rows and columns for the dataframe

df.shape
print(f'There are {df.shape[0]} rows, and {df.shape[1]} columns.')
print(f'The rows represent {df.shape[0]} observations, and the columns represent {df.shape[1]-1} features and 1 target variable.')
# Out:
# There are 5110 rows, and 11 columns.
# The rows represent 5110 observations, and the columns represent 10 features and 1 target variable.

# %% [markdown]
# Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
 # Displaying column names and datatypes

df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %% [markdown]
# Need to convert 'age' from a float to an int

# %% [markdown]
# Checking object categories to see which ones to ordinal encode

# %%
# Inspect categorical columns for errors

cat_cols = make_column_selector(dtype_include='object')(df)
for col in cat_cols:
  display(df[col].value_counts(normalize=True))
# Out:
# Female    0.585910
# Male      0.413894
# Other     0.000196
# Name: gender, dtype: float64
# Yes    0.656164
# No     0.343836
# Name: ever_married, dtype: float64
# Private          0.572407
# Self-employed    0.160274
# children         0.134442
# Govt_job         0.128571
# Never_worked     0.004305
# Name: work_type, dtype: float64
# Urban    0.508023
# Rural    0.491977
# Name: Residence_type, dtype: float64
# never smoked       0.370254
# Unknown            0.302153
# formerly smoked    0.173190
# smokes             0.154403
# Name: smoking_status, dtype: float64

# %% [markdown]
# # Ordinal Encoding

# %% [markdown]
# 'gender', 'ever_married', and 'Residence_type'

# %%
# Replace boolean values with 0s and 1s

df['gender'].replace({'Female':1, 'Male':0, 'Other':0}, inplace=True)
# replace other with 'Male' using ordinal encoding 

df['ever_married'].replace({'No':0, 'Yes':1}, inplace=True)

df['Residence_type'].replace({'Urban':0, 'Rural':1}, inplace=True)


# Rename 'Gender' to 'isfemale' for clarity
df.rename(columns={'gender':'isfemale'}, inplace=True)

df[['isfemale', 'ever_married', 'Residence_type']].value_counts()
# Out:
# isfemale  ever_married  Residence_type
# 1         1             0                 1028
#                         1                  973
# 0         1             0                  683
#                         1                  669
# 1         0             0                  501
#                         1                  492
# 0         0             0                  384
#                         1                  380
# dtype: int64

# %% [markdown]
# ever_married and Residence_type only have 2 values so we gave it a binary value.
#
# gender has 3 values but 'other' only appears one time in this data set

# %%
# Inspect numerical columns for errors

num_cols = make_column_selector(dtype_include='number')(df)
for col in num_cols:
  display(df[col].value_counts(normalize=True))
# Out:
# 1    0.58591
# 0    0.41409
# Name: isfemale, dtype: float64
# 78.00    0.019961
# 57.00    0.018591
# 52.00    0.017613
# 54.00    0.017025
# 51.00    0.016830
#            ...
# 1.40     0.000587
# 0.48     0.000587
# 0.16     0.000587
# 0.40     0.000391
# 0.08     0.000391
# Name: age, Length: 104, dtype: float64
# 0    0.902544
# 1    0.097456
# Name: hypertension, dtype: float64
# 0    0.945988
# 1    0.054012
# Name: heart_disease, dtype: float64
# 1    0.656164
# 0    0.343836
# Name: ever_married, dtype: float64
# 0    0.508023
# 1    0.491977
# Name: Residence_type, dtype: float64
# 93.88     0.001174
# 91.68     0.000978
# 91.85     0.000978
# 83.16     0.000978
# 73.00     0.000978
#             ...
# 111.93    0.000196
# 94.40     0.000196
# 95.57     0.000196
# 66.29     0.000196
# 85.28     0.000196
# Name: avg_glucose_level, Length: 3979, dtype: float64
# 28.7    0.008352
# 28.4    0.007741
# 26.7    0.007537
# 27.6    0.007537
# 26.1    0.007537
#           ...
# 48.7    0.000204
# 49.2    0.000204
# 51.0    0.000204
# 49.4    0.000204
# 14.9    0.000204
# Name: bmi, Length: 418, dtype: float64
# 0    0.951272
# 1    0.048728
# Name: stroke, dtype: float64

# %%
# converting 'age' from float to int

df['age'] = df['age'].apply(np.int64)

# %% [markdown]
# # Checking for missing data

# %%
## Display the total number of missing values

print(f'There are {df.isna().sum().sum()} missing values.')
# Out:
# There are 201 missing values.

# %%
# Confirming where the missing data is coming from

df.isna().sum()
# Out:
# isfemale               0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# We will handle the missing data in 'bmi' later when we are splitting the data

# %%
import seaborn as sns

sns.barplot(data = df, x = 'smoking_status', y = 'stroke', hue='isfemale');

# %% [markdown]
# This graph shows that those who formerly smoked are more than likely to have a stroke. Even a higher chance than those who are currently smoking

# %%
sns.barplot(data = df, x = 'work_type', y = 'stroke', hue='isfemale');

# %% [markdown]
# Both male and female who are self employed are more than likely to get a stroke meanwhile those who never worked have close to no chance of having a stroke

# %%
sns.barplot(data = df, x = 'work_type', y = 'bmi', hue='isfemale');

# %% [markdown]
# So it seems as if those who are in the work force have a much higher BMI than those who are not. Even those who are self employed who seem to have the highest BMI of them all.

# %%
ax = df['bmi'].hist(bins = 30, edgecolor = 'black')
ax.tick_params(axis='x')
ax.set_title('BMI of Patients')
ax.set_xlabel('BMI')
ax.set_ylabel('Number of patients at X BMI');

# %% [markdown]
# the majority of the clients BMIs are under 30
#
# it is clear as well that smoking does not help with weight loss nor does it increase weight gain because our BMIs are all over the place.

# %%
# Horizontal boxplot with Seaborn

ax = sns.boxplot(x='age', data=df)
ax.set_title("Age of Clients");

# %% [markdown]
# The average age is inbetween 22 and 61 while the median age is 43
#
# while the lowest age is 1 and the highest age is 83

# %%
fig, ax = plt.subplots(figsize=(15,5))

sns.heatmap(df.corr(), cmap = 'Purples', annot = True);
# Out:
# <ipython-input-20-e3cc63ee879f>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap = 'Purples', annot = True);

# %% [markdown]
# Based on this heatmap I do not have many coorolations other than 'ever_married' & 'age' which is at .68

# %%
# Explore numeric distributions
for col in df.select_dtypes('number'):
  plt.title(col.capitalize() + ' of Patients')
  print('\n', col, '\n')
  df[col].hist()
  plt.show()
# Out:
#  isfemale
#  age
#  hypertension
#  heart_disease
#  ever_married
#  Residence_type
#  avg_glucose_level
#  bmi
#  stroke

# %%
fig, ax = plt.subplots(figsize=(15,5))

sns.countplot(data = df, y = 'smoking_status', order = df['smoking_status'].value_counts().index)

ax.set(title = 'Smoking Status')
ax.set(ylabel = 'smoking_status');

# %%
fig, ax = plt.subplots(figsize=(15,5))

sns.countplot(data = df, y = 'work_type', order = df['work_type'].value_counts().index)

ax.set(title = 'Work Type')
ax.set(ylabel = 'Work Type');

# %%
sns.set(font_scale=1)
sns.scatterplot(x='bmi', y='work_type', 
    data=df).set(title='BMI vs Work Type')
plt.xlabel(
    'BMI')
plt.ylabel('Work Type');

# %% [markdown]
# Accoring to this chart, those who have a private work type tend to tred on having a higher BMI where as the childern and those who have never worked are much lower on average

# %%
sns.set(font_scale=1)
sns.scatterplot(x='avg_glucose_level', y='work_type', 
    data=df).set(title='Avg Glucose Level vs Work Type')
plt.xlabel(
    'Avg Glucose Level')
plt.ylabel('Work Type');

# %% [markdown]
# Based off of this chart unless you are a child or never worked your glugose level are off the charts unless the majority of people just finsihed eating before being tested.

# %% [markdown]
# Based off of the two scatter plots we can see that those with a private work type have a high BMI and average glucose level.
#
# Those who are children and never worked have a lower BMI and lower average glucose level.
#
# I am very suprised to see that children on average have a higher BMI and glucose level than those who never work because the odds are that children also never worked before.

# %% [markdown]
# # Part 4

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import make_column_selector, make_column_transformer, ColumnTransformer 
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, recall_score, precision_score, \
f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn import set_config
set_config(display = 'diagram')

# %%
# search for missing values
df.isna().sum()
# Out:
# isfemale               0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
y = df['stroke']

X = df.drop(columns = ['stroke'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Instantiate column selectors
## number selector
num_sel = make_column_selector(dtype_include='number')
cat_sel = make_column_selector(dtype_include='object')

# Instantiate Mean Imputer
median_imputer = SimpleImputer(strategy='median')

# Instantiate Transformers
## Scaler for numeric
scaler = StandardScaler()
ohe = OneHotEncoder()

# Pipeline
num_pipe = make_pipeline(median_imputer, scaler)

# Tuple for column transformer
num_tup = (num_pipe, num_sel)
cat_tup = (ohe, cat_sel)

# ColumnTransformer
preprocessor = make_column_transformer(num_tup, cat_tup, remainder='drop')

#Fit Preprocessor
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('pipeline',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f105033d460>),
#                                 ('onehotencoder', OneHotEncoder(),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f105033d5e0>)])

# %%
# Create an instance of the model
knn = KNeighborsClassifier()

# Create a model pipeline
knn_pipe = make_pipeline(preprocessor, knn)

# Fit the model
knn_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f105033d460>),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f105033d5e0>)])),
#                 ('kneighborsclassifier', KNeighborsClassifier())])

# %%
# Predictions
knn_train_preds = knn_pipe.predict(X_train)
knn_test_preds = knn_pipe.predict(X_test)

# Print Classification Report for predictions
print('train')
print(classification_report(y_train, knn_train_preds))

print('test')
print(classification_report(y_test, knn_test_preds))
# Out:
# train
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      3663
#            1       0.73      0.05      0.09       169
#
#     accuracy                           0.96      3832
#    macro avg       0.84      0.52      0.53      3832
# weighted avg       0.95      0.96      0.94      3832
#
# test
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1198
#            1       0.00      0.00      0.00        80
#
#     accuracy                           0.94      1278
#    macro avg       0.47      0.50      0.48      1278
# weighted avg       0.88      0.94      0.91      1278

# %%
# Plot the confusion matrix
# labels=['Stroke','No Stroke']
ConfusionMatrixDisplay.from_predictions(y_test, knn_test_preds, 
                                        cmap='Blues');

plt.show()

# %%
knn_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('pipeline',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='median')),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308ba00>),
#                                    ('onehotencoder', OneHotEncoder(),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308b6d0>)])),
#   ('kneighborsclassifier', KNeighborsClassifier())],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('pipeline',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer(strategy='median')),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308ba00>),
#                                  ('onehotencoder', OneHotEncoder(),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308b6d0>)]),
#  'kneighborsclassifier': KNeighborsClassifier(),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('pipeline',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                    ('standardscaler', StandardScaler())]),
#    <sklearn.compose._column_transformer.make_column_selector at 0x7f105308ba00>),
#   ('onehotencoder',
#    OneHotEncoder(),
#    <sklearn.compose._column_transformer.make_column_selector at 0x7f105308b6d0>)],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'columntransformer__pipeline': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                  ('standardscaler', StandardScaler())]),
#  'columntransformer__onehotencoder': OneHotEncoder(),
#  'columntransformer__pipeline__memory': None,
#  'columntransformer__pipeline__steps': [('simpleimputer',
#    SimpleImputer(strategy='median')),
#   ('standardscaler', StandardScaler())],
#  'columntransformer__pipeline__verbose': False,
#  'columntransformer__pipeline__simpleimputer': SimpleImputer(strategy='median'),
#  'columntransformer__pipeline__standardscaler': StandardScaler(),
#  'columntransformer__pipeline__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline__simpleimputer__copy': True,
#  'columntransformer__pipeline__simpleimputer__fill_value': None,
#  'columntransformer__pipeline__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline__simpleimputer__strategy': 'median',
#  'columntransformer__pipeline__simpleimputer__verbose': 'deprecated',
#  'columntransformer__pipeline__standardscaler__copy': True,
#  'columntransformer__pipeline__standardscaler__with_mean': True,
#  'columntransformer__pipeline__standardscaler__with_std': True,
#  'columntransformer__onehotencoder__categories': 'auto',
#  'columntransformer__onehotencoder__drop': None,
#  'columntransformer__onehotencoder__dtype': numpy.float64,
#  'columntransformer__onehotencoder__handle_unknown': 'error',
#  'columntransformer__onehotencoder__max_categories': None,
#  'columntransformer__onehotencoder__min_frequency': None,
#  'columntransformer__onehotencoder__sparse': 'deprecated',
#  'columntransformer__onehotencoder__sparse_output': True,
#  'kneighborsclassifier__algorithm': 'auto',
#  'kneighborsclassifier__leaf_size': 30,
#  'kneighborsclassifier__metric': 'minkowski',
#  'kneighborsclassifier__metric_params': None,
#  'kneighborsclassifier__n_jobs': None,
#  'kneighborsclassifier__n_neighbors': 5,
#  'kneighborsclassifier__p': 2,
#  'kneighborsclassifier__weights': 'uniform'}

# %%
# Create and visualize our parameter grid

knn_param_grid = {'kneighborsclassifier__n_neighbors': [5,10,15],
                 'kneighborsclassifier__p': [2,3,4],
                 'kneighborsclassifier__weights': ['uniform']}

knn_GS = GridSearchCV(knn_pipe, knn_param_grid)

knn_GS.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308ba00>),
#                                                                         ('onehotencoder',
#                                                                          OneHotEncoder(),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308b6d0>)])),
#                                        ('kneighborsclassifier',
#                                         KNeighborsClassifier())]),
#              param_grid={'kneighborsclassifier__n_neighbors': [5, 10, 15],
#                          'kneighborsclassifier__p': [2, 3, 4],
#                          'kneighborsclassifier__weights': ['uniform']})

# %%
# print best parameters
print('Best Decision Tree Parameters:')
print(knn_GS.best_params_)

# print accuracy using .best_estimator
knn_best = knn_GS.best_estimator_
print(f'Accuracy of Decision Tree Model: {knn_best.score(X_test, y_test)}')
# Out:
# Best Decision Tree Parameters:
# {'kneighborsclassifier__n_neighbors': 10, 'kneighborsclassifier__p': 2, 'kneighborsclassifier__weights': 'uniform'}
# Accuracy of Decision Tree Model: 0.9374021909233177

# %%
knn_tuned = KNeighborsClassifier(n_neighbors=10, p=2, weights='uniform')

# Pipeline for preprocossor and rf_tuned
knn_tuned_pipe = make_pipeline(preprocessor,knn_tuned)

# Fitting tuned pipe
knn_tuned_pipe.fit(X_train, y_train)

# predictions on tuned pipe
knn2_train_pred = knn_tuned_pipe.predict(X_train)
knn2_test_pred = knn_tuned_pipe.predict(X_test)

# %%
print('Training tuned classification')
print(classification_report(y_train, knn2_train_pred))
print('\n')
print('Testing tuned classification')
print(classification_report(y_test, knn2_test_pred))
# Out:
# Training tuned classification
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      3663
#            1       1.00      0.01      0.01       169
#
#     accuracy                           0.96      3832
#    macro avg       0.98      0.50      0.49      3832
# weighted avg       0.96      0.96      0.93      3832
#
#
#
# Testing tuned classification
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1198
#            1       0.00      0.00      0.00        80
#
#     accuracy                           0.94      1278
#    macro avg       0.47      0.50      0.48      1278
# weighted avg       0.88      0.94      0.91      1278
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Plot the confusion matrix
labels=['Stroke','No Stroke']
ConfusionMatrixDisplay.from_predictions(y_test, knn2_test_pred, 
                                        display_labels=labels, 
                                        cmap='Purples', normalize='true');

# %% [markdown]
# # RandomForest

# %%
# Create an instance of the model
rf = RandomForestClassifier()

# Create a model pipeline
rf_pipe = make_pipeline(preprocessor, rf)

# Fit the model
rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308ba00>),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308b6d0>)])),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
# Predictions
rf_train_preds = rf_pipe.predict(X_train)
rf_test_preds = rf_pipe.predict(X_test)

# Print Classification Report for predictions
print('train')
print(classification_report(y_train, rf_train_preds))

print('test')
print(classification_report(y_test, rf_test_preds))
# Out:
# train
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3663
#            1       1.00      1.00      1.00       169
#
#     accuracy                           1.00      3832
#    macro avg       1.00      1.00      1.00      3832
# weighted avg       1.00      1.00      1.00      3832
#
# test
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1198
#            1       0.00      0.00      0.00        80
#
#     accuracy                           0.94      1278
#    macro avg       0.47      0.50      0.48      1278
# weighted avg       0.88      0.94      0.91      1278
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Plot the confusion matrix
labels=['Stroke','No Stroke']
ConfusionMatrixDisplay.from_predictions(y_test, rf_test_preds, 
                                        display_labels=labels, 
                                        cmap='Greens', normalize='true');

# %%
rf_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('pipeline',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='median')),
#                                                     ('standardscaler',
#                                                      StandardScaler())]),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308ba00>),
#                                    ('onehotencoder', OneHotEncoder(),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308b6d0>)])),
#   ('randomforestclassifier', RandomForestClassifier())],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('pipeline',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer(strategy='median')),
#                                                   ('standardscaler',
#                                                    StandardScaler())]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308ba00>),
#                                  ('onehotencoder', OneHotEncoder(),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308b6d0>)]),
#  'randomforestclassifier': RandomForestClassifier(),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('pipeline',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                    ('standardscaler', StandardScaler())]),
#    <sklearn.compose._column_transformer.make_column_selector at 0x7f105308ba00>),
#   ('onehotencoder',
#    OneHotEncoder(),
#    <sklearn.compose._column_transformer.make_column_selector at 0x7f105308b6d0>)],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'columntransformer__pipeline': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                  ('standardscaler', StandardScaler())]),
#  'columntransformer__onehotencoder': OneHotEncoder(),
#  'columntransformer__pipeline__memory': None,
#  'columntransformer__pipeline__steps': [('simpleimputer',
#    SimpleImputer(strategy='median')),
#   ('standardscaler', StandardScaler())],
#  'columntransformer__pipeline__verbose': False,
#  'columntransformer__pipeline__simpleimputer': SimpleImputer(strategy='median'),
#  'columntransformer__pipeline__standardscaler': StandardScaler(),
#  'columntransformer__pipeline__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline__simpleimputer__copy': True,
#  'columntransformer__pipeline__simpleimputer__fill_value': None,
#  'columntransformer__pipeline__simpleimputer__keep_empty_features': False,
#  'columntransformer__pipeline__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline__simpleimputer__strategy': 'median',
#  'columntransformer__pipeline__simpleimputer__verbose': 'deprecated',
#  'columntransformer__pipeline__standardscaler__copy': True,
#  'columntransformer__pipeline__standardscaler__with_mean': True,
#  'columntransformer__pipeline__standardscaler__with_std': True,
#  'columntransformer__onehotencoder__categories': 'auto',
#  'columntransformer__onehotencoder__drop': None,
#  'columntransformer__onehotencoder__dtype': numpy.float64,
#  'columntransformer__onehotencoder__handle_unknown': 'error',
#  'columntransformer__onehotencoder__max_categories': None,
#  'columntransformer__onehotencoder__min_frequency': None,
#  'columntransformer__onehotencoder__sparse': 'deprecated',
#  'columntransformer__onehotencoder__sparse_output': True,
#  'randomforestclassifier__bootstrap': True,
#  'randomforestclassifier__ccp_alpha': 0.0,
#  'randomforestclassifier__class_weight': None,
#  'randomforestclassifier__criterion': 'gini',
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__max_features': 'sqrt',
#  'randomforestclassifier__max_leaf_nodes': None,
#  'randomforestclassifier__max_samples': None,
#  'randomforestclassifier__min_impurity_decrease': 0.0,
#  'randomforestclassifier__min_samples_leaf': 1,
#  'randomforestclassifier__min_samples_split': 2,
#  'randomforestclassifier__min_weight_fraction_leaf': 0.0,
#  'randomforestclassifier__n_estimators': 100,
#  'randomforestclassifier__n_jobs': None,
#  'randomforestclassifier__oob_score': False,
#  'randomforestclassifier__random_state': None,
#  'randomforestclassifier__verbose': 0,
#  'randomforestclassifier__warm_start': False}

# %%
# Create and visualize our parameter grid

rf_param_grid = {'randomforestclassifier__max_depth': [3,5,7],
                 'randomforestclassifier__min_samples_split': [2,3,4]}

rf_GS = GridSearchCV(rf_pipe, rf_param_grid)

rf_GS.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308ba00>),
#                                                                         ('onehotencoder',
#                                                                          OneHotEncoder(),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7f105308b6d0>)])),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier())]),
#              param_grid={'randomforestclassifier__max_depth': [3, 5, 7],
#                          'randomforestclassifier__min_samples_split': [2, 3,
#                                                                        4]})

# %%
# print best parameters
print('Best Decision Tree Parameters:')
print(rf_GS.best_params_)

# print accuracy using .best_estimator
rf_best = rf_GS.best_estimator_
print(f'Accuracy of Decision Tree Model: {rf_best.score(X_test, y_test)}')
# Out:
# Best Decision Tree Parameters:
# {'randomforestclassifier__max_depth': 3, 'randomforestclassifier__min_samples_split': 2}
# Accuracy of Decision Tree Model: 0.9374021909233177

# %%
rf_tuned = RandomForestClassifier(max_depth=3, min_samples_leaf=2)

# Pipeline for preprocossor and rf_tuned
rf_tuned_pipe = make_pipeline(preprocessor,rf_tuned)

# Fitting tuned pipe
rf_tuned_pipe.fit(X_train, y_train)

# predictions on tuned pipe
rf2_train_pred = rf_tuned_pipe.predict(X_train)
rf2_test_pred = rf_tuned_pipe.predict(X_test)

# %%
print('Training tuned classification')
print(classification_report(y_train, rf2_train_pred))
print('\n')
print('Testing tuned classification')
print(classification_report(y_test, rf2_test_pred))
# Out:
# Training tuned classification
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      3663
#            1       0.00      0.00      0.00       169
#
#     accuracy                           0.96      3832
#    macro avg       0.48      0.50      0.49      3832
# weighted avg       0.91      0.96      0.93      3832
#
#
#
# Testing tuned classification
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1198
#            1       0.00      0.00      0.00        80
#
#     accuracy                           0.94      1278
#    macro avg       0.47      0.50      0.48      1278
# weighted avg       0.88      0.94      0.91      1278
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Plot the confusion matrix
labels=['Stroke','No Stroke']
ConfusionMatrixDisplay.from_predictions(y_test, rf2_test_pred, 
                                        display_labels=labels, 
                                        cmap='Oranges', normalize='true');

# %% [markdown]
# # PCA with KNN

# %%
# Instantiate
pca = PCA(n_components=.95)

# %%
# model
knn_pca = KNeighborsClassifier()

# Creating pipeline with scaler
transformer = make_pipeline(preprocessor, pca)

# creating model pipeline with transformer
KNN_pcs = make_pipeline(transformer, knn_pca)

# %%
# train with pca
# %timeit KNN_pcs.fit(X_train, y_train)
# Out:
# 45.6 ms ± 15.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Save model for test data set
# %timeit KNN_test_pred = KNN_pcs.predict(X_test)
# Out:
# 65.2 ms ± 2.41 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# checking accuracy 
print('Testing Accuracy:', KNN_pcs.score(X_test, y_test))
# Out:
# Testing Accuracy: 0.9358372456964006

# %% [markdown]
# # PCA with RF

# %%
# model
rf_pca = RandomForestClassifier()

# Creating pipeline with scaler
transformer = make_pipeline(preprocessor, pca)

# creating model pipeline with transformer
RF_pcs = make_pipeline(transformer, rf_pca)

# %%
# train with pca
# %timeit RF_pcs.fit(X_train, y_train)
# Out:
# 1.4 s ± 204 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Save model for test data set
# %timeit RF_test_pred = RF_pcs.predict(X_test)
# Out:
# 35.5 ms ± 1.23 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# checking accuracy 
print('Testing Accuracy:', RF_pcs.score(X_test, y_test))
# Out:
# Testing Accuracy: 0.9366197183098591

# %% [markdown]
# Both KNN & RF models gave us 94% accuarcy. Based on my experience RF tends to yeild better results. So as more data is collected I will contiue to lean more on RF.
